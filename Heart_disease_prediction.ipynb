# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib.cm import rainbow
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-8d60c9b0-1b4f-4a7a-adc2-59b4e1255556" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8d60c9b0-1b4f-4a7a-adc2-59b4e1255556">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving heart.csv to heart.csv

# %%
df=pd.read_csv('heart.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   age                                   270 non-null    int64
#  1   sex                                   270 non-null    int64
#  2   chest                                 270 non-null    int64
#  3   resting_blood_pressure                270 non-null    int64
#  4   serum_cholestoral                     270 non-null    int64
#  5   fasting_blood_sugar                   270 non-null    int64
#  6   resting_electrocardiographic_results  270 non-null    int64
#  7   maximum_heart_rate_achieved           270 non-null    int64
#  8   exercise_induced_angina               270 non-null    int64
#  9   oldpeak                               270 non-null    float64
#  10  slope                                 270 non-null    int64
#  11  number_of_major_vessels               270 non-null    int64
#  12  thal                                  270 non-null    int64
#  13  class                                 270 non-null    object
# dtypes: float64(1), int64(12), object(1)
# memory usage: 29.7+ KB

# %%
df.describe()
# Out:
#               age         sex  ...  number_of_major_vessels        thal
# count  270.000000  270.000000  ...               270.000000  270.000000
# mean    54.433333    0.677778  ...                 0.670370    4.696296
# std      9.109067    0.468195  ...                 0.943896    1.940659
# min     29.000000    0.000000  ...                 0.000000    3.000000
# 25%     48.000000    0.000000  ...                 0.000000    3.000000
# 50%     55.000000    1.000000  ...                 0.000000    3.000000
# 75%     61.000000    1.000000  ...                 1.000000    7.000000
# max     77.000000    1.000000  ...                 3.000000    7.000000
#
# [8 rows x 13 columns]

# %%
import seaborn as sns
corrmat=df.corr()
top_corr_features=corrmat.index
plt.figure(figsize=(20,20))
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0d732415c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0d731ed6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0d731a0940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0d731d5ba8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0d73189e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0d7314b0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0d730fd320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0d730b2550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0d730b25c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0d73019a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0d7304dcc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0d73002f28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f0d72fc21d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0d72f74438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0d72f296a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f0d72edd908>]],
#       dtype=object)

# %%
sns.set_style('whitegrid')
sns.countplot(x='thal',data=df,palette='RdBu_r')

# %%
sns.set_style('whitegrid')
sns.countplot(x='maximum_heart_rate_achieved',data=df,palette='RdBu_r')

# %%
dataset=pd.get_dummies(df,columns=['sex','age','chest','oldpeak','thal'])

# %%
dataset.head()
# Out:
#    resting_blood_pressure  serum_cholestoral  ...  thal_6  thal_7
# 0                     130                322  ...       0       0
# 1                     115                564  ...       0       1
# 2                     124                261  ...       0       1
# 3                     128                263  ...       0       1
# 4                     120                269  ...       0       0
#
# [5 rows x 98 columns]
